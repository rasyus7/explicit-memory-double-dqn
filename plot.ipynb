# %% [markdown]
# # Plotting

# %% [markdown]
# ## v1-question_prob=1.0
#
# There is one different thing in the RoomEnv from the original AAAI-2023 paper: The reward is either +1 or -1, instead of +1 or 0.

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import logging

logging.disable()

from plotting import (
    plot_training_validation_results,
    plot_test_results,
    plot_test_results_all_capacities,
)
from utils import read_json

plot_training_validation_results(
    data_dir="./data/v1-question_prob=1.0/",
    kind="train_loss",
    capacity=32,
    save_dir="./figures/",
    ymin=None,
    ymax=None,
    ylog=True,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="upper right",
)

plot_training_validation_results(
    data_dir="./data/v1-question_prob=1.0/",
    kind="val_total_reward_mean",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    ylog=False,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="lower right",
)

plot_test_results(
    data_dir="./data/v1-question_prob=1.0/",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    des_size="l",
    figsize=(10, 10),
    legend_loc="upper left",
    question_prob=1.0,
    allow_random_human=False,
    allow_random_question=False,
)

plot_test_results_all_capacities(
    data_dir="./data/v1-question_prob=1.0/",
    save_dir="./figures/",
    ymin=-128,
    ymax=128,
    des_size="l",
    figsize=(25, 8),
    legend_loc="upper left",
    question_prob=1.0,
    allow_random_human=False,
    allow_random_question=False,
)

test_debug_scratch_path = "./models/v1-question_prob=1.0/allow_random_human=False_allow_random_question=False_pretrain_semantic=False_varying_rewards=False_des_size=l_capacity=32_question_prob=1.0_seed=2/test_debug-mean=95.0-std=6.017.json"
test_debug_scratch = read_json(test_debug_scratch_path)["0"]
test_debug_pretrained_path = "./models/v1-question_prob=1.0/allow_random_human=False_allow_random_question=False_pretrain_semantic=True_varying_rewards=False_des_size=l_capacity=32_question_prob=1.0_seed=0/test_debug-mean=114.2-std=5.828.json"
test_debug_pretrained = read_json(test_debug_pretrained_path)["0"]

for step in [42]:
    print(f"STEP: {step}")
    print()
    print(f"SCRATCH: {test_debug_scratch[step]}")
    print()
    print(f"PRETRAINED: {test_debug_pretrained[step]}")
    print()
    print(
        "----------------------------------------------------------------------------"
    )
# Out:
# heights: 50.4, stds: 8.429
# heights: 58.0, stds: 9.381
# heights: 33.8, stds: 9.569
# heights: 89.32000122070312, stds: 4.021143669546528
# heights: 110.71999969482422, stds: 3.5181795198362273
# STEP: 42
#
# SCRATCH: {'state': ["[{'human': 'Ann', 'object': 'bowl', 'object_location': 'cupboard', 'timestamp': 2}, {'human': 'Anthony', 'object': 'sheep', 'object_location': 'farm', 'timestamp': 3}, {'human': 'Arthur', 'object': 'donut', 'object_location': 'bakery', 'timestamp': 4}, {'human': 'Barbara', 'object': 'donut', 'object_location': 'lap', 'timestamp': 5}, {'human': 'Brenda', 'object': 'bowl', 'object_location': 'farm', 'timestamp': 8}, {'human': 'Brittany', 'object': 'keyboard', 'object_location': 'cupboard', 'timestamp': 9}, {'human': 'Catherine', 'object': 'bicycle', 'object_location': 'home', 'timestamp': 12}, {'human': 'Christopher', 'object': 'sheep', 'object_location': 'movie', 'timestamp': 14}, {'human': 'Donald', 'object': 'dog', 'object_location': 'kitchen', 'timestamp': 17}, {'human': 'Frank', 'object': 'train', 'object_location': 'circus', 'timestamp': 22}, {'human': 'Gloria', 'object': 'sheep', 'object_location': 'lap', 'timestamp': 23}, {'human': 'Isabella', 'object': 'train', 'object_location': 'kitchen', 'timestamp': 25}, {'human': 'James', 'object': 'bicycle', 'object_location': 'nursery', 'timestamp': 28}, {'human': 'Larry', 'object': 'airplane', 'object_location': 'cupboard', 'timestamp': 39}]", "[{'object': 'bicycle', 'object_location': 'countryside', 'num_generalized': 1}, {'object': 'bird', 'object_location': 'countryside', 'num_generalized': 1}, {'object': 'airplane', 'object_location': 'circus', 'num_generalized': 1}, {'object': 'handbag', 'object_location': 'store', 'num_generalized': 1}, {'object': 'sheep', 'object_location': 'cupboard', 'num_generalized': 1}, {'object': 'bird', 'object_location': 'tree', 'num_generalized': 1}, {'object': 'bird', 'object_location': 'kitchen', 'num_generalized': 1}, {'object': 'boat', 'object_location': 'lunchbox', 'num_generalized': 1}, {'object': 'oven', 'object_location': 'home', 'num_generalized': 2}, {'object': 'car', 'object_location': 'city', 'num_generalized': 2}, {'object': 'keyboard', 'object_location': 'desk', 'num_generalized': 2}, {'object': 'elephant', 'object_location': 'circus', 'num_generalized': 2}, {'object': 'bowl', 'object_location': 'cupboard', 'num_generalized': 2}, {'object': 'sandwich', 'object_location': 'lunchbox', 'num_generalized': 2}, {'object': 'train', 'object_location': 'zoo', 'num_generalized': 3}, {'object': 'kite', 'object_location': 'air', 'num_generalized': 3}]", "[{'human': 'Linda', 'object': 'handbag', 'object_location': 'store', 'timestamp': 42}]"], 'q_values': [[2.225620746612549, 2.4189727306365967, 2.322629451751709]], 'step': 42}
#
# PRETRAINED: {'state': ["[{'human': 'Barbara', 'object': 'donut', 'object_location': 'lap', 'timestamp': 5}, {'human': 'Brenda', 'object': 'bowl', 'object_location': 'farm', 'timestamp': 8}, {'human': 'Brittany', 'object': 'keyboard', 'object_location': 'cupboard', 'timestamp': 9}, {'human': 'Carl', 'object': 'airplane', 'object_location': 'circus', 'timestamp': 10}, {'human': 'Catherine', 'object': 'bicycle', 'object_location': 'home', 'timestamp': 12}, {'human': 'Christopher', 'object': 'sheep', 'object_location': 'movie', 'timestamp': 14}, {'human': 'David', 'object': 'boat', 'object_location': 'lunchbox', 'timestamp': 15}, {'human': 'Diana', 'object': 'oven', 'object_location': 'home', 'timestamp': 16}, {'human': 'Donald', 'object': 'dog', 'object_location': 'kitchen', 'timestamp': 17}, {'human': 'Frank', 'object': 'train', 'object_location': 'circus', 'timestamp': 22}, {'human': 'Gloria', 'object': 'sheep', 'object_location': 'lap', 'timestamp': 23}, {'human': 'Isabella', 'object': 'train', 'object_location': 'kitchen', 'timestamp': 25}, {'human': 'James', 'object': 'bicycle', 'object_location': 'nursery', 'timestamp': 28}, {'human': 'Keith', 'object': 'sheep', 'object_location': 'cupboard', 'timestamp': 38}, {'human': 'Larry', 'object': 'airplane', 'object_location': 'cupboard', 'timestamp': 39}, {'human': 'Lauren', 'object': 'bird', 'object_location': 'countryside', 'timestamp': 41}]", "[{'object': 'bowl', 'object_location': 'cupboard', 'num_generalized': 1}, {'object': 'dog', 'object_location': 'kennel', 'num_generalized': 1}, {'object': 'keyboard', 'object_location': 'desk', 'num_generalized': 1}, {'object': 'elephant', 'object_location': 'circus', 'num_generalized': 1}, {'object': 'bird', 'object_location': 'tree', 'num_generalized': 1}, {'object': 'oven', 'object_location': 'home', 'num_generalized': 1}, {'object': 'sandwich', 'object_location': 'lunchbox', 'num_generalized': 1}, {'object': 'handbag', 'object_location': 'store', 'num_generalized': 1}, {'object': 'donut', 'object_location': 'bakery', 'num_generalized': 1}, {'object': 'car', 'object_location': 'city', 'num_generalized': 1}, {'object': 'airplane', 'object_location': 'sky', 'num_generalized': 1}, {'object': 'boat', 'object_location': 'water', 'num_generalized': 1}, {'object': 'train', 'object_location': 'zoo', 'num_generalized': 1}, {'object': 'bicycle', 'object_location': 'garage', 'num_generalized': 1}, {'object': 'sheep', 'object_location': 'farm', 'num_generalized': 1}, {'object': 'kite', 'object_location': 'air', 'num_generalized': 1}]", "[{'human': 'Linda', 'object': 'handbag', 'object_location': 'store', 'timestamp': 42}]"], 'q_values': [[2.6292691230773926, 2.6267552375793457, 2.718707323074341]], 'step': 42}
#
# ----------------------------------------------------------------------------

# %% [markdown]
# ## Everything same as the above, except that double dqn is used.
# sync_rate=10

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import logging

logging.disable()

from plotting import (
    plot_training_validation_results,
    plot_test_results,
    plot_test_results_all_capacities,
)
from utils import read_json

plot_training_validation_results(
    data_dir="./data/v1-ddqn-question_prob=1.0-sync_rate=10/",
    kind="train_loss",
    capacity=32,
    save_dir="./figures/",
    ymin=None,
    ymax=None,
    ylog=True,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="upper right",
)

plot_training_validation_results(
    data_dir="./data/v1-ddqn-question_prob=1.0-sync_rate=10/",
    kind="val_total_reward_mean",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    ylog=False,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="lower right",
)

plot_test_results(
    data_dir="./data/v1-ddqn-question_prob=1.0-sync_rate=10/",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    des_size="l",
    figsize=(10, 10),
    legend_loc="upper left",
    question_prob=1.0,
    allow_random_human=False,
    allow_random_question=False,
)
# Out:
# heights: 50.4, stds: 8.429
# heights: 58.0, stds: 9.381
# heights: 33.8, stds: 9.569
# heights: 90.23999938964843, stds: 4.126790526405994
# heights: 108.2, stds: 4.630334761116596

# %% [markdown]
# ## Everything same as the above, except that double dqn is used.
# sync_rate=20

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import logging

logging.disable()

from plotting import (
    plot_training_validation_results,
    plot_test_results,
    plot_test_results_all_capacities,
)
from utils import read_json

plot_training_validation_results(
    data_dir="./data/v1-ddqn-question_prob=1.0-sync_rate=20/",
    kind="train_loss",
    capacity=32,
    save_dir="./figures/",
    ymin=None,
    ymax=None,
    ylog=True,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="upper right",
)

plot_training_validation_results(
    data_dir="./data/v1-ddqn-question_prob=1.0-sync_rate=20/",
    kind="val_total_reward_mean",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    ylog=False,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="lower right",
)

plot_test_results(
    data_dir="./data/v1-ddqn-question_prob=1.0-sync_rate=20/",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    des_size="l",
    figsize=(10, 10),
    legend_loc="upper left",
    question_prob=1.0,
    allow_random_human=False,
    allow_random_question=False,
)
# Out:
# heights: 50.4, stds: 8.429
# heights: 58.0, stds: 9.381
# heights: 33.8, stds: 9.569
# heights: 96.16000061035156, stds: 6.778083462874221
# heights: 105.92000122070313, stds: 3.6673682582212184

# %% [markdown]
# ## Everything same as the above, except that dueling dqn is used. (no ddqn)

# %%
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)

import logging

logging.disable()

from plotting import (
    plot_training_validation_results,
    plot_test_results,
    plot_test_results_all_capacities,
)
from utils import read_json

plot_training_validation_results(
    data_dir="./data/v1-dueling/",
    kind="train_loss",
    capacity=32,
    save_dir="./figures/",
    ymin=None,
    ymax=None,
    ylog=True,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="upper right",
)

plot_training_validation_results(
    data_dir="./data/v1-dueling/",
    kind="val_total_reward_mean",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    ylog=False,
    xlabel="Step",
    figsize=(10, 10),
    legend_loc="lower right",
)

plot_test_results(
    data_dir="./data/v1-dueling/",
    capacity=32,
    save_dir="./figures/",
    ymin=0,
    ymax=120,
    des_size="l",
    figsize=(10, 10),
    legend_loc="upper left",
    question_prob=1.0,
    allow_random_human=False,
    allow_random_question=False,
)
# Out:
# heights: 50.4, stds: 8.429
# heights: 56.6, stds: 10.278
# heights: 37.6, stds: 9.541
# heights: 81.43999786376953, stds: 5.868424004191357
# heights: 102.71999816894531, stds: 8.92421501438912
